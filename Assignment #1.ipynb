# %% [markdown]
# ### Assignment Set 1 by [Pegah Khazaei](https://github.com/pegahkhazaeii/Deep_Learning_F20_Assignments) for [Deep Learing](https://github.com/hhaji/Deep-Learning) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import tensorflow as tf
import torch

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("TensorFlow Version: ", tf.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.22.1
# TensorFlow Version:  1.13.1
# PyTorch Version:  1.6.0

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0 -0.409804  1.182054  0.532155  0.439163 -0.174804
# 1 -0.877779 -0.268328  1.147030  0.634766  0.262134
# 2  0.910171 -0.121419  0.109076 -1.621382 -0.167006
# 3 -0.639803  1.242503  0.393625 -0.448940  0.697909
# 4  0.219262  1.259567  0.214915 -1.414530  0.162315
# 5  0.692146 -0.028382  2.380002  1.679747  3.023832
# 6 -0.968660 -0.759048 -1.485546  0.505913  0.815207
# 7 -0.325734 -1.379881 -0.648739  0.005536 -1.630554
# 8 -0.260192 -0.784849  0.377414 -2.414334 -0.275521
# 9 -1.284378 -0.110496  0.593735 -0.554029 -1.554676
#
# -> Execution Time = 22.80898952484131 in Seconds <-
