# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34578947551_863af3acb3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16242239484_51286673af.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34697163155_5dc2571f23_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34686041416_e50c8028f9_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/31530587330_ba31bd196e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/flickr.py
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16837594326_1056d875a4_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14164392167_650946a169_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34592557281_5f254b3a46_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/20179380768_7a2990d4e3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34583574661_8010a1fdf4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/flickr.pyc
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19440660848_c789227129_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34719957845_c929f480a3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16510864164_3afa8ac37f.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34351602790_37234e2dae_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33626882480_8b2345a63c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34335240590_41e4a393db_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34549305152_15f407a771_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18243329421_771b4d938e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34653465656_31bc613631_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34695057206_98de825612_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19551343814_48f764535f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33071081032_a6a1e4b311_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16970837587_4a9d8500d7.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34692530906_fe2470a5e5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17574213074_f5416afd84.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14914603395_b271ffab56_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15219268336_f2460fca88_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33886917763_2db539f182_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18232119726_cef27eaaac_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17122969189_0ec37cb6c9.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14362539701_cf19e588ca.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15123503538_8ee984abc6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33913495873_b582be4fdf_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17189437699_a9171b6ae3.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14368895004_c486a29c1e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15358221063_2c6e548e84.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34323484476_6406ee1e37_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19426575569_4b53c0b726.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14128835667_b6a916222c.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34587934371_1a0429111e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/22274701614_901606ee34_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34365073265_246c5c0561_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34604698981_89d8741b10_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34527583252_79aafda601_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/27446317092_ff9bb852d5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14886963928_d4856f1eb6_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34724303275_b9494837aa_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/23659122395_3467d88c02_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33199895303_9858f0a258_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33924521963_48cdc4f455_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18276105805_d31d3f7e71.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34690477346_6af75b993b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/27186992702_449dfa54ef_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14171812905_8b81d50eb9_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17080000869_a80e767f4a_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18111636378_856027a7b8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34575269471_fe82b32aa9_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/23414449869_ee849a80d4.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34721329895_529f999fb6_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34571582172_efa4946a45_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34605411661_4e735bd995_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17161833794_e1d92259d2_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18010259565_d6aae33ca7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34711474235_507d286bce_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/22196426956_eca94f6faa_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34709307795_994ddf0eb5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/22190242684_8c3300d4e6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15821571649_06c4b9a868_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14457225751_645a3784fd_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14404468648_37903d7025_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14740350060_a489d9fa06.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34323645656_afd53a9996_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33873410454_04bc2167f4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18243351371_5fda92ac0a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14728922673_99086a3818_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16241101274_334b54731e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34725992285_21cb05733a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34694292346_83b4d97809_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34560984002_254f326f12_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14335561523_f847f2f4f1.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/22785985545_95464115b0_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34335432530_cd667cbb19_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19435491090_7af558e17e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17047385027_8fd510e164_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33876197394_c7a9487a9f_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34352075020_61ac834f5a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16953818045_fea21c8bf8.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17020815734_81e8db8008_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33877585464_b23cefb361_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15002906952_cab2cb29cf.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34587720941_ccbbc420ec_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34256868592_ca3ffd6b15_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19602790836_912d38aaa8.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33877696673_2d1de2d252_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34562347042_e4dc06879a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/29535628436_2e79a9628d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/21657726011_2c94e341bc_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14554897292_b3e30e52f2.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18876985840_7531dc8e6a.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17649230811_9bdbbacb8c.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14202166370_e989588332.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34699848885_a832ee03ab_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16716172029_2166d8717f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34719559905_46ba779d79_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33885269993_3968e1aacc_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/20983660733_06b35b9eb8.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/29687446176_096b86f44c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16817037661_2980d823e1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14576445793_582aa6446b_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17619402434_15b2ec2d79.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15819121091_26a5243340_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16911008669_ea21fd8915_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34551360172_dde3b8e43d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34551666432_c5b5f9684e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17243540220_65b98eb926_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17344936845_fec4d626b7.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34690508115_bafcb9845c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18996760154_58d3c48604.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17388674711_6dca8a2e8b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34725991045_05812dedd5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14648777167_1d92d403c9_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17095758258_a33642946f_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19067907051_16d530c7d2.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19617425002_b914c1e2ab.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34603214751_8b42379b53_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33852722714_496828f866_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17175932454_c052e205c1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17146644679_11aff3045c.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19506262462_d0945c14a6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/21523597492_39b6765cd7_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17688233756_21879104c1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19622465055_2a62ebd504_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17077940105_d2cd7b9ec4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14313509432_6f2343d6c8_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16495282564_d8c34d6a2e_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16766166609_ccb8344c9f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18482768066_677292a64e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14128839257_23def53028.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/23192507093_2e6ec77bef_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33849982914_0f017c8e3c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18970601002_d70bc883a9.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/32120685303_90b5f21ab2_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34662996866_af256e8f10_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34694287966_43ce068108_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14439618952_470224b89b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17482158576_86c5ebc2f8.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18183515403_13a9ca6d86_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33925191623_d355f976ef_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34654530326_6dcda41377_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34525649892_e2ea3eb051_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18479635994_83f93f4120.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16691236594_4287cea9d6_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/23891393761_155af6402c.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17457028309_95514c8d02_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18687587599_3dd4fdf255.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34599366451_2854aee943_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34334194690_0dfe3d8701_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16949657389_ac0ee80fd1_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14396023703_11c5dd35a9.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33892886253_7c74efdd7a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34561332721_04b6f1c889_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34662979916_0479576f5e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34571561452_07ec474366_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14126515096_1134fae695.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18996957833_0bd71fbbd4_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18215579866_94b1732f24.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33847542834_0ce330ac60_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33914172633_592a6eb74f_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/29138994986_267e0e36c9_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16863587471_cc3a6ffb29_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34343228430_8df9f1c03a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18204150090_fb418bbddb.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33881308394_738a121eb3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34584449441_576a1336b1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15381511376_fd743b7330_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18238604119_a5689980ee_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17322195031_c2680809dc_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/32701230112_a33f8003a5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16375088191_2bf2916b53.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33851560384_d2e7d933db_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34717754295_cbb0185a36_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34338412180_a1f4faa1e7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14886860069_b84665a073.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16656127943_2f70926b6c.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33878004304_a7c823115b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/27166475803_f5503f51f8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33857437664_f2ddb77592_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19617643201_9922eec796.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/20456824132_b1c8fbfa41_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/26741270544_f44f3a1b19_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33875520194_09bff6f262_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34550871222_a9d795a2c0_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19004688463_12a8423109.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33904560113_497239a68f_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14376454225_a1de336c5b.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16237158409_01913cf918_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33980437760_60f3ceaf03_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15782158700_3b9bf7d33e_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17388697431_0d84c427d1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33909432943_bf810400b7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34311470786_5b2b5bea1d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34678209886_9005f29b47_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18996965033_1d92e5c99e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17047231499_bd66c23641.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17280886635_e384d91300_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34536491752_dd130e7b79_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19526570282_1d1e71b0f3_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17346385582_7ba433dbbe.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15547944931_c1e095b185.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17851831751_35b071f4b0.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18587334446_ef1021909b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34562659841_caba988a0c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34582964591_dc9f160fce_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17420983523_2e32d70359.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18089878729_907ed2c7cd_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14373114081_7922bcf765_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17862580326_293070978d_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/run_me.py
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34601267911_00c92c9a04_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/29556932571_f124d8ac5d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17135145776_4c2ec21b05_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33881120324_552f677c1a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18271576032_d7e2296de4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19621170705_30bf8bf0ba.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15005530987_e13b328047_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19551343954_83bb52f310_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19443726008_8c9c68efa7_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15139657325_74031c44fc.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14185089716_2a48298d17.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34722644565_812fcc1397_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16462263826_2555edeb74_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16713229021_bea2533981_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17747738311_5014b1f77f.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33878218914_452600b869_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14093744313_b66bc95072.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33522989504_542fde1a1a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34533729452_7d8e2b519d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33886931523_4499a65b72_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33852722314_e8907d51f1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34571238031_7eff74ca43_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34555389922_8da9ffa268_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34339792440_8224ca420d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17821459748_873101edd0_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14805304536_c321a7b061_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14845607659_1be18c5d7f.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19613308325_a67792d889.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18803577858_fd0036e1f5_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15297244181_011883a631_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14375349004_68d893254a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33857574164_b0b724b567_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18282528206_7fb3166041.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19593576916_f5a083d7fe_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14093789753_f0f1acdb57.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34690479536_69da7b98e7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/22679060358_561ec823ae_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15644450971_6a28298454_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16096748028_7876887ab2.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34729107795_c746845e17_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16699732794_5bfd639cf8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19438516548_bbaf350664.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33875742534_31b85d1b05_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34694280496_d457f0d7b7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19600096066_67dc941042.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34552250422_320900fd8e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34727715205_62c9c1ac44_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34689593326_0fd3fbc38a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19599413676_fc9ee2640e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34604803411_99956ac67a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14884028290_a1344eb446.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14199664556_188b37e51e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19691175559_ef12b8b354_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34568232012_2e771f16f8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17244252705_328e0bcda6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34732908685_a219574ffe_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/27299697786_75340698c5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34591866681_ff35af51df_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14455605089_8bbfb41cd7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18999743619_cec3f39bee.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33859759654_be0be6f876_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33882910234_dd8f1479e3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19626311985_58f1a79da3.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16650892835_9228a3ef67_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14306875733_61d71c64c0_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15549402199_2890918ddb.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19437578578_6ab1b3c984.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15268682367_5a4512b29f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17466568484_9128287148.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14200639491_2a4611916d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17367866236_61abd4d243_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19443674130_08db1d9578_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17276354745_2e312a72b5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34700475225_fbc12d0834_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34591174681_483f7cb82a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/26004221274_74900d17e1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18304194360_2a4a0be631_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33877749474_1fb8111daf_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17147436650_c94ae24004_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33875654554_e5e4070fab_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18889216716_cd67aec890_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19812060274_c432f603db.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34310456510_a4ceda64da_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/29157239893_f43793c697_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14211880544_5d1f9d5aa8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34647026976_68af8875e0_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33877161494_05686b7f7a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19437710780_c5f2156438.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/32558425090_d6b6e86d85_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19961979110_fcd8092388_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17903104293_9138439e76.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17570530696_6a497298ee_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17831860736_3e44667bbb_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14761980161_2d6dbaa4bb_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19617501581_606be5f716_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/16744522344_8d21b1530d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14278605962_d3cce5522f.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34537877932_f9a3476a4d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18385846351_3a2bf60427_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19586799286_beb9d684b5.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14292205986_da230467ef.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19440910519_cb1162470e.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18342918441_b1bb69a2fd_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14469481104_d0e29f7ffd.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17075803866_aeeded2637.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34728513735_ebb4b179eb_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18995294384_77543e96b6_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/18001393975_2a6acaabd8.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33856267954_b806fab0db_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33869330174_b259025135_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33841565863_7ab8c1e23c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34588967411_84b348245b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34234226791_63a2afc7ed_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19064700925_b93d474e37.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34679936936_9924d79c8d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/15378782362_4161b23af7_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17029965300_8e755c2214_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33892172244_684e99b6fc_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34351608230_f95038a5a4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34346200780_c3a783a3ec_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33850973214_c1b4000d9c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/19397467530_1e8131a7cf.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33890085903_0e10553b27_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34206776142_941d75c2ed_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34540904752_ae86e5f6ce_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/14614655810_9910e6dbd6_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/34586667251_bfda649f33_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/17220096449_0e535989f0_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/dandelion/33907694863_f7c0f23ef3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34670512115_af22cce24d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19280272025_57de24e940_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34695914906_961f92ffcd_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/15813862117_dedcd1c56f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34602180741_cf2f671ba5_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34518066912_0e432507bc_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34554334542_7d8f68a75c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34546791291_eb8e15e18a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34310869690_56cdc84a17_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34524074031_e42b9b1acd_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34500610132_9921740f71_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18195689904_46619b7e16_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33806101464_5eca772954_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19544831049_0d738d4872_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33838292353_8b143f7980_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18354545086_693ea7bc2a.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34661399476_9ea7e2fd53_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20948886919_cac7844f34_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/17027891179_3edc08f4f6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18679421522_3be9879e32.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34326606950_41ff8997d7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34613530216_26cf037012_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33872893913_72d64a9b85_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34729724865_787c98299d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33830843653_ee6d7989fa_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34696730346_5f0c131e59_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18711159980_11d3bd5042.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16291797949_a1b1b7c2bd_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34637970155_a2b917077c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/29821115270_eccd3866e1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34293871550_71d1e4d482_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/17101762155_2577a28395.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33863293993_3ed7515936_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34693373736_9ce6d9e1c3_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34485028892_fc238ddfc8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33810542134_a493f19a71_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/27400851831_fe08fbcb66_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20580471306_ab5a011b15_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34664107325_701d5c6f08_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33890808514_ca21f75499_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34611565966_9de274f987_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34266044490_01dacd2ac2_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16527403771_2391f137c4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34727863665_b00ac77266_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16161045294_70c76ce846_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34342014230_4230ae8e08_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34532930772_5cc5fc600d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16482676953_5296227d40_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/21805938544_bf6bb0e4bc.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/21402054779_759366efb0_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16819071290_471d99e166_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34517409722_829ec7e152_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33802431204_7c58f4e21b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33855966243_01b2486428_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34530932101_957fab3650_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34524085651_1f0b7e9497_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19653086178_28156b7ce4_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16737503507_431768a927.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20685027271_0e7306e7c1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34326847400_f4de801005_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16577886423_9b23622f1d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19178753159_a471bf4b6b.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33819069114_6ecc240b54_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34638378196_216d5bbc2e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/22873310415_3a5674ec10_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18635898912_eb8e058ef0.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16020253176_60f2a6a5ca_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18023717391_e2c9089e10.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/29380234244_c50a60374e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18400014056_2e4c601ed5.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34547261352_d39bf4073a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34293312980_5f6c492c52_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18474740346_ffdaa18032.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34733243845_29f1c30634_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34546994701_a000b283f1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33843400403_db00aa16b8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20329326505_a777c71cc2.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33859244503_eeeca6a397_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34590677231_0ed33ccd55_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34571214621_f655295459_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/15760153042_a2a90e9da5_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34539556222_f7ba32f704_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34520699571_f880744f46_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33901756843_94e198d40e_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34591991761_16fc5c9c00_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34287492780_6dab677857_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33884228533_91b75ff4d4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34312496620_bc01a98aeb_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34522174462_b7cbee3ecb_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33814092924_b23d019011_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33846706663_5f4695ffa4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34266042310_9c1abd8e11_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33837577463_1ae52a3726_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34637394046_f85541735d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/14907815010_bff495449f.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33887503434_a2762228f4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/17357636476_1953c07aa4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19019544592_b64469bf84_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33809174824_00ba798039_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34520690871_8fe693bc71_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33918001783_06a692e371_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20289938802_e16fa9f23d.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/15784493690_b1858cdb2b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/15760811380_4d686c892b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34275152390_44e7262261_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/28056118836_77a6847d94_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16056178001_bebc2153fe_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16360180712_b72695928c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34288158610_6e42406193_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20703737132_179560d0fb.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33885735373_444ba02d9c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18582579815_4c6637e9ff_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19813618946_93818db7aa_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34720703615_bdf1335d8b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34540113401_b81594e92a_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34540176411_a35a19a8ef_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33880234094_2541c9c83d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34337108550_0b619aa726_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34518374242_310e7abd54_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33857335804_7f0c96243b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34682895116_88ef018e83_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16025261368_911703a536_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19527362416_8bdcbefb8b_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16121105382_b96251e506_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34275662120_7757a15d07_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/15306268004_4680ba95e1.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33911247013_82a1acfcea_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34531542152_c8ba2e0fea_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34076975155_1faeedec90_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34585331601_837dbe5254_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/18203367608_07a04e98a4_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33849854704_d2a2415e4d_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34696729796_190b1dfdf1_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33843240613_0b736f9896_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/23095658544_7226386954_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34562146951_cf3d2a627c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19177263840_6a316ea639.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/17249393016_093e915012_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/19834392829_7d697871f6.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16833748795_b681b2839f_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/20619292635_9857a12d54.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/14921511479_7b0a647795.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34696730126_056ffea63c_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33871813063_d7b6bedafe_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34283646340_4fe48d1bb7_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/16401288243_36112bd52f_m.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/34585995071_13e07140d8_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33923454163_9cabcaa733_n.jpg
# /kaggle/input/flower-classification/flowers_/flowers_/test/daisy/33858238653_6549e21f53_n.jpg
# ...
# /kaggle/input/flower-classification/flowers_/train/rose/14166797345_d2ab9da518.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16545641666_2781e542a0_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7481118128_b2de9538b4_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7376473742_532364cee5_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002453148_5a7bbcce64_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002450022_33337e895b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002453464_ab2bcb3829_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5415783734_b002ebce24_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17062080069_36ac7907d2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5693492187_dc46424be3_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7345657862_689366e79a.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8181940917_1ac63937d5_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5180896559_b8cfefc21e.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9614492283_66020fb4eb_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16424992340_c1d9eb72b4.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18464075576_4e496e7d42_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335944839_a3b6168534_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349250331_05501d6557_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/33568244695_7ec846bcc6_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7481119180_7be71a322a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18486123042_5c8da68f38_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335936311_390e8ed5d9_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/31050510212_73d570592a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18486146942_e09ecd0e25_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9160289562_ab2718d19b.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14414123198_24606fb32d.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7471891186_195bb02c98_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5717319579_190e85c7d1_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8272822550_fc49484186_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001857777_440e725f2f_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16018886851_c32746cb72.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15811411368_f4f2cd8873_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336551122_2df8fee6da_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9167147034_0a66ee3616_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5181899042_0a6ffe0c8a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336555402_4f6f03f5a5_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8437935944_aab997560a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5693486585_cf64d87519_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335945309_852d018a27_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/22385375599_1faf334f5d_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/13342823005_16d3df58df_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6209630964_e8de48fe04_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5415782938_6ce6e4a90d_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7461897646_3203dbe067_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/22506717337_0fd63e53e9.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17869810353_c0d9902bc3_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15509799653_0562d4a4fa.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002456992_4da0df247a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/21346056089_e6f8074e5f_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001853739_e293f7b268_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349249729_be6b2cac86_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001848135_63300a26a8_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16670921315_0fc48d7ab2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14993880427_95d0f27257.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335937417_74a03b52ec_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/12434194695_a7c4e73c6b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7302931078_30054c1970_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/12165480946_c4a3fe182d_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9338237628_4d2547608c.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9353111163_7a89b2df35_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001843683_ac3e5f2c87_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/33185001420_dc8f571c4f_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/13235124703_a7e1266e44.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/11233672494_d8bf0a3dbf_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18302796110_02ef47cd43_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8523394349_61b31fdd8f_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18220342690_f1c20134bd.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5060536705_b370a5c543_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/12406229175_82e2ac649c_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8241471746_5d81fdd3c0_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5292988046_a10f4b0365_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7461898018_7e12128f14_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14381787252_e8e12e277a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/22982871191_ec61e36939_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7474126688_5f888ace5b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/33411423082_8150d9254e_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001854143_d868390640_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7474126248_889a026929_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7470985338_a1f3bba601_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16772483324_09f24813a1_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8337607102_d9e0fa887e.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349250145_960c51d4fc_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335936115_0292d0beef_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5526964611_76ef13025c_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/19566556880_476c66c5ee_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7316409504_7cf3707f8a_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15972976206_d32feeb79b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6732261031_861a1026fa_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8279801891_5369a6c3c1_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/4900231976_f8ced2b42a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8050213579_48e1e7109f.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6864417932_36fa4ceecf_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336560370_f994cb35a1_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7376471712_e1be793f94.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7481119492_a0016cb059_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15821959372_518b9dcf57_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15697872479_ed48e9dd73_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7865295712_bcc94d120c.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7456198272_f5d0c6bc7e_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8035908422_87220425d2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001846495_56068de2da_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002447434_9b06760f63_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14460517566_783dbf23b8_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336549532_49c711d49a_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/4910094611_8c7170fc95_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7525783408_0999483bf4_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15972975956_9a770ca9dd_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5088766459_f81f50e57d_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18486171962_c46dbd067d_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15312360171_57bde98799_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9309388105_12c0b8dd54_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5694090698_1f0c218250_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14747962886_2bff6bb323_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349860036_389d912fb7_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16643785404_284c6c23fe_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349254467_388ff94f8b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15699509054_d3e125286f_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14573732424_1bb91e2e42_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7456914664_cdee3170c5_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15236835789_6009b8f33d.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17104364030_ee31ee279b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6125332325_b768e08bd9_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002452834_167883dbcf_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14810868100_87eb739f26_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16152175716_55d6968e08_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8273451349_acd4748da6_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16157873719_bf0bdf8558_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001846301_9380fbe900_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/13211873833_82b029c8a1_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7683456068_02644b8382_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14414100710_753a36fce9.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8949720453_66e8304c30.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/18302691898_9dc45afae8_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/9369421752_db1ab2a6a4_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/4951581805_b049304f1b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6363951285_a802238d4e.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5083072098_81587295d5.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7461898754_9032a38963_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336545886_7b93463c06_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5156037859_1673720a11_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14597445311_8acb60247e.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/10090824183_d02c613f10_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7474125638_332be2863e_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15965652160_de91389965_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001856549_7e0a640488_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17867791274_25bb3f8a41_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14943194730_f48b4d4547_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8301512319_45185c447f_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5336551618_16d4eea9c4_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5693502877_41c11295b6_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7474124984_ca015e8c10_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17302463621_d82be11f01_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5835539224_75967fc400_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8960904651_9a0b727258.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17990320484_93bba345d2_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5061135742_2870a7b691_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/12243068283_ee4c2683e2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349865556_e3263fbdc0_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/13231224664_4af5293a37.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7456771390_c2505e08a2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5349249547_5cde2db97c_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001847255_34ff6146ec_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001847693_77a9fb4f3c_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/19440805164_920b28da61_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16484100863_979beacb08.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6231418894_7946a7712b_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/13979889721_42a59ca9fa_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/14154164774_3b39d36778.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/12238827553_cf427bfd51_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7461878736_a55f749faf_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/17158274118_00ec99a23c.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6241886381_cc722785af.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7456196174_f9de97ba73_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8742493617_c2a9bf854f_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5002455332_9de0b1e85f_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/22325299158_6e32e599f8_m.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/15999816377_4b95e0b538_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8747396730_966149e6fe_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/16001846141_393fdb887e_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/6879112993_5a29208438_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7456196908_d34b9b76c4_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5694071486_90c2b1aee5_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/19919867648_043cf02fc3.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335945781_e45852fa49_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5693495337_0e42b4d9f0_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5001852517_6a8713ffe2_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/7820626638_3e2d712303.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5148639829_781eb7d346.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/5335946401_f49bfbe3f9_n.jpg
# /kaggle/input/flower-classification/flowers_/train/rose/8063462557_e0a8bd6c64_n.jpg

# %%
import torch
from torchvision import datasets, transforms, models
from torch.autograd import Variable
import numpy as np
from matplotlib import pyplot as plt

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

data_dir = "../input/flower-classification/flowers_/"

train_transform = transforms.Compose([
                                transforms.Resize(150),
                                transforms.RandomResizedCrop(150),
                                transforms.RandomHorizontalFlip(),
                                transforms.ColorJitter(),
                                transforms.ToTensor(),
                                transforms.Normalize(mean, std)])

test_transform = transforms.Compose([
                                transforms.Resize(150),
                                transforms.CenterCrop(150),
                                transforms.ToTensor(),
                                transforms.Normalize(mean, std)])

train_data  = datasets.ImageFolder(data_dir + '/train', train_transform)
test_data = datasets.ImageFolder(data_dir + '/test', test_transform)

# %%
classes = train_data.classes
class_idx = train_data.class_to_idx
class_idx
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=100,
                                           shuffle=True,
                                           num_workers=1)

test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=100,
                                          shuffle=False,
                                          num_workers=1)

print(len(train_loader))
# Out:
# 31

# %%
images , labels = next(iter(train_loader))
images.shape, len(labels)
# Out:
# (torch.Size([100, 3, 150, 150]), 100)

# %%
# visualize data
import numpy as np
import matplotlib.pyplot as plt

data_iter = iter(test_loader)
images, labels = data_iter.next()

fig = plt.figure(figsize=(25, 5))
for idx in range(2):
    ax = fig.add_subplot(1, 5, idx + 1, xticks=[], yticks=[])
    # unnormolaize first
    img = images[idx] / 2 + 0.5
    npimg = img.numpy()
    img = np.transpose(npimg, (1, 2, 0)) #transpose
    ax.imshow(img, cmap='gray')
    ax.set_title(classes[labels[idx]])

# %%
model = models.resnet50(pretrained=True)
model.fc
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Linear(in_features=2048, out_features=1000, bias=True)

# %%
for param in model.parameters():
    param.required_grad = False

# %%
import torch.nn as nn
from collections import OrderedDict

classifier = nn.Sequential(
  nn.Linear(in_features=2048, out_features=1024),
  nn.LeakyReLU(),
  nn.Dropout(p=0.2),
  nn.Linear(in_features=1024, out_features=512),
  nn.LeakyReLU(),
  nn.Dropout(p=0.3),
  nn.Linear(in_features=512, out_features=5),
  nn.LogSoftmax(dim=1)  
)
    
model.fc = classifier
model.fc
# Out:
# Sequential(
#   (0): Linear(in_features=2048, out_features=1024, bias=True)
#   (1): LeakyReLU(negative_slope=0.01)
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=1024, out_features=512, bias=True)
#   (4): LeakyReLU(negative_slope=0.01)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Linear(in_features=512, out_features=5, bias=True)
#   (7): LogSoftmax(dim=1)
# )

# %%
import torch.optim as optim
import torch

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.003)
#gpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=5, bias=True)
#     (7): LogSoftmax(dim=1)
#   )
# )

# %%
n_epochs = 5

# compare overfited
train_loss_data,valid_loss_data = [],[]

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

class_correct = list(0. for i in range(5))
class_total = list(0. for i in range(5))

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # Move input and label tensors to the default device
        data, target = data.to(device), target.to(device)
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item() #*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in test_loader:
        # Move input and label tensors to the default device
        data, target = data.to(device), target.to(device)
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item() #*data.size(0)
        # convert output probabilities to predicted class
        _, pred = torch.max(output, 1)
        # compare predictions to true label
        correct = np.squeeze(pred.eq(target.data.view_as(pred)))
        # calculate test accuracy for each object class
        for i in range(16):
          label = target.data[i]
          class_correct[label] += correct[i].item()
          class_total[label] += 1
        
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(test_loader.dataset)
    
    #clculate train loss and running loss
    train_loss_data.append(train_loss)
    valid_loss_data.append(valid_loss)
    
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1,
        n_epochs,
        train_loss,
        valid_loss
        ))
    print('\t\tTest Accuracy: %4d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('\t\tValidation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
