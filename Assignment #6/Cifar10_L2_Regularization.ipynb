# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np
 
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

# %% [markdown]
# # nonregularized_model

# %%
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
 
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
batch_size = 64
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# train the network
model.fit(x_train, y_train, epochs=40, batch_size=batch_size)

# validate the model on test dataset to determine generalization
score = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Epoch 1/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5771 - accuracy: 0.7973
# Epoch 2/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5677 - accuracy: 0.8003
# Epoch 3/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5494 - accuracy: 0.8057
# Epoch 4/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5482 - accuracy: 0.8104
# Epoch 5/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5397 - accuracy: 0.8116
# Epoch 6/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5243 - accuracy: 0.8158
# Epoch 7/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.5156 - accuracy: 0.8198
# Epoch 8/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5051 - accuracy: 0.8235
# Epoch 9/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4984 - accuracy: 0.8255
# Epoch 10/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4876 - accuracy: 0.8291
# Epoch 11/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4864 - accuracy: 0.8287
# Epoch 12/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4734 - accuracy: 0.8326
# Epoch 13/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4692 - accuracy: 0.8345
# Epoch 14/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4582 - accuracy: 0.8403
# Epoch 15/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4482 - accuracy: 0.8428
# Epoch 16/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4413 - accuracy: 0.8445
# Epoch 17/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4381 - accuracy: 0.8465
# Epoch 18/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4231 - accuracy: 0.8498
# Epoch 19/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4240 - accuracy: 0.8500
# Epoch 20/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4173 - accuracy: 0.8519
# Epoch 21/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4078 - accuracy: 0.8556
# Epoch 22/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.4027 - accuracy: 0.8565
# Epoch 23/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3922 - accuracy: 0.8619
# Epoch 24/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3943 - accuracy: 0.8606
# Epoch 25/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3822 - accuracy: 0.8649
# Epoch 26/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3777 - accuracy: 0.8645
# Epoch 27/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3727 - accuracy: 0.8672
# Epoch 28/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3698 - accuracy: 0.8683
# Epoch 29/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3603 - accuracy: 0.8721
# Epoch 30/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3513 - accuracy: 0.8746
# Epoch 31/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3491 - accuracy: 0.8760
# Epoch 32/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3438 - accuracy: 0.8770
# Epoch 33/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3375 - accuracy: 0.8794
# Epoch 34/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3299 - accuracy: 0.8824
# Epoch 35/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3297 - accuracy: 0.8835
# Epoch 36/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3167 - accuracy: 0.8867
# Epoch 37/40
# 782/782 [==============================] - 15s 20ms/step - loss: 0.3142 - accuracy: 0.8880
# Epoch 38/40
# 782/782 [==============================] - 16s 21ms/step - loss: 0.3143 - accuracy: 0.8886
# Epoch 39/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3098 - accuracy: 0.8888
# Epoch 40/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3017 - accuracy: 0.8919
# 157/157 [==============================] - 1s 8ms/step - loss: 0.4806 - accuracy: 0.8442
#
# Test accuracy: 84.4%

# %% [markdown]
# # regularized_model

# %%
weight_decay = 1e-4
l2regularized_model = Sequential()
l2regularized_model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(MaxPooling2D(pool_size=(2,2)))
l2regularized_model.add(Dropout(0.2))
 
l2regularized_model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(MaxPooling2D(pool_size=(2,2)))
l2regularized_model.add(Dropout(0.3))
 
l2regularized_model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
l2regularized_model.add(Activation('elu'))
l2regularized_model.add(BatchNormalization())
l2regularized_model.add(MaxPooling2D(pool_size=(2,2)))
l2regularized_model.add(Dropout(0.4))
 
l2regularized_model.add(Flatten())
l2regularized_model.add(Dense(num_classes, activation='softmax'))
 
l2regularized_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_24 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_26 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_27 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_28 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_29 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
batch_size = 64
l2regularized_model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# train the network
l2regularized_model.fit(x_train, y_train, epochs=40, batch_size=batch_size)

# validate the model on test dataset to determine generalization
score = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Epoch 1/40
# 782/782 [==============================] - 16s 20ms/step - loss: 1.9398 - accuracy: 0.4169
# Epoch 2/40
# 782/782 [==============================] - 16s 20ms/step - loss: 1.3545 - accuracy: 0.5551
# Epoch 3/40
# 782/782 [==============================] - 16s 20ms/step - loss: 1.1339 - accuracy: 0.6230
# Epoch 4/40
# 782/782 [==============================] - 16s 20ms/step - loss: 1.0388 - accuracy: 0.6552
# Epoch 5/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.9614 - accuracy: 0.6786
# Epoch 6/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.9154 - accuracy: 0.6947
# Epoch 7/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.8731 - accuracy: 0.7092
# Epoch 8/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.8414 - accuracy: 0.7197
# Epoch 9/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.8132 - accuracy: 0.7290
# Epoch 10/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7848 - accuracy: 0.7391
# Epoch 11/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7623 - accuracy: 0.7472
# Epoch 12/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7426 - accuracy: 0.7520
# Epoch 13/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7271 - accuracy: 0.7590
# Epoch 14/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7092 - accuracy: 0.7653
# Epoch 15/40
# 782/782 [==============================] - 16s 21ms/step - loss: 0.6926 - accuracy: 0.7724
# Epoch 16/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6747 - accuracy: 0.7784
# Epoch 17/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6627 - accuracy: 0.7821
# Epoch 18/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6438 - accuracy: 0.7887
# Epoch 19/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6346 - accuracy: 0.7906
# Epoch 20/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6209 - accuracy: 0.7971
# Epoch 21/40
# 782/782 [==============================] - 17s 21ms/step - loss: 0.6075 - accuracy: 0.7998
# Epoch 22/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5934 - accuracy: 0.8039
# Epoch 23/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5838 - accuracy: 0.8088
# Epoch 24/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5763 - accuracy: 0.8114
# Epoch 25/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5631 - accuracy: 0.8159
# Epoch 26/40
# 782/782 [==============================] - 16s 21ms/step - loss: 0.5530 - accuracy: 0.8200
# Epoch 27/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5457 - accuracy: 0.8210
# Epoch 28/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5340 - accuracy: 0.8269
# Epoch 29/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5265 - accuracy: 0.8274
# Epoch 30/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5136 - accuracy: 0.8332
# Epoch 31/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5061 - accuracy: 0.8359
# Epoch 32/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4989 - accuracy: 0.8381
# Epoch 33/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4971 - accuracy: 0.8383
# Epoch 34/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4842 - accuracy: 0.8427
# Epoch 35/40
# 782/782 [==============================] - 16s 21ms/step - loss: 0.4760 - accuracy: 0.8476
# Epoch 36/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4650 - accuracy: 0.8508
# Epoch 37/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4571 - accuracy: 0.8526
# Epoch 38/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4559 - accuracy: 0.8530
# Epoch 39/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4469 - accuracy: 0.8546
# Epoch 40/40
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4413 - accuracy: 0.8585
# 157/157 [==============================] - 1s 8ms/step - loss: 0.4806 - accuracy: 0.8442
#
# Test accuracy: 84.4%
